# %% [markdown]
# ### Resnet50 exploration

# %%
import os
import pandas as pd
from pathlib import Path
from tensorflow.keras.applications import ResNet50

# %%
# path settings
project_path = Path(os.getcwd(), os.pardir)
output_path = project_path / "output"

# %%
resnet50 = ResNet50(include_top=False, weights='imagenet', pooling=None, input_shape=(96, 128, 3))
# Out:
# /Users/salomon/miniconda3/envs/experiments/lib/python3.6/site-packages/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '

# %%
all_config_keys = []
for layer in resnet50.get_config()['layers']:
    for k, v in layer['config'].items():
        if k not in all_config_keys:
            all_config_keys.append(k)

# %%
df = pd.DataFrame(columns=['layer_id', 'name'] + all_config_keys)

# %%
output = []
for i, l in enumerate(resnet50.get_config()['layers']):
    row = {}
    row['_layer_id'] = i
    row['_name'] = l['name']
    print(f"{i} name: {l['name']}")
    for k, v in l['config'].items():
        row[k] = v
        print(f"- {k}: {v}" )
    output.append(row)
# Out:
# 0 name: input_2
# - batch_input_shape: (None, 96, 128, 3)
# - dtype: float32
# - sparse: False
# - name: input_2
# 1 name: conv1_pad
# - name: conv1_pad
# - trainable: True
# - dtype: float32
# - padding: ((3, 3), (3, 3))
# - data_format: channels_last
# 2 name: conv1
# - name: conv1
# - trainable: True
# - dtype: float32
# - filters: 64
# - kernel_size: (7, 7)
# - strides: (2, 2)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 3 name: bn_conv1
# - name: bn_conv1
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 4 name: activation_49
# - name: activation_49
# - trainable: True
# - dtype: float32
# - activation: relu
# 5 name: pool1_pad
# - name: pool1_pad
# - trainable: True
# - dtype: float32
# - padding: ((1, 1), (1, 1))
# - data_format: channels_last
# 6 name: max_pooling2d_1
# - name: max_pooling2d_1
# - trainable: True
# - dtype: float32
# - pool_size: (3, 3)
# - padding: valid
# - strides: (2, 2)
# - data_format: channels_last
# 7 name: res2a_branch2a
# - name: res2a_branch2a
# - trainable: True
# - dtype: float32
# - filters: 64
# - kernel_size: (1, 1)
# - strides: (1, 1)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 8 name: bn2a_branch2a
# - name: bn2a_branch2a
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 9 name: activation_50
# - name: activation_50
# - trainable: True
# - dtype: float32
# - activation: relu
# 10 name: res2a_branch2b
# - name: res2a_branch2b
# - trainable: True
# - dtype: float32
# - filters: 64
# - kernel_size: (3, 3)
# - strides: (1, 1)
# - padding: same
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 11 name: bn2a_branch2b
# - name: bn2a_branch2b
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 12 name: activation_51
# - name: activation_51
# - trainable: True
# - dtype: float32
# - activation: relu
# 13 name: res2a_branch2c
# - name: res2a_branch2c
# - trainable: True
# - dtype: float32
# - filters: 256
# - kernel_size: (1, 1)
# - strides: (1, 1)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 14 name: res2a_branch1
# - name: res2a_branch1
# - trainable: True
# - dtype: float32
# - filters: 256
# - kernel_size: (1, 1)
# - strides: (1, 1)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 15 name: bn2a_branch2c
# - name: bn2a_branch2c
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 16 name: bn2a_branch1
# - name: bn2a_branch1
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 17 name: add_16
# - name: add_16
# - trainable: True
# - dtype: float32
# 18 name: activation_52
# - name: activation_52
# - trainable: True
# - dtype: float32
# - activation: relu
# 19 name: res2b_branch2a
# - name: res2b_branch2a
# - trainable: True
# - dtype: float32
# - filters: 64
# - kernel_size: (1, 1)
# - strides: (1, 1)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 20 name: bn2b_branch2a
# - name: bn2b_branch2a
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 21 name: activation_53
# - name: activation_53
# - trainable: True
# - dtype: float32
# - activation: relu
# 22 name: res2b_branch2b
# - name: res2b_branch2b
# - trainable: True
# - dtype: float32
# - filters: 64
# - kernel_size: (3, 3)
# - strides: (1, 1)
# - padding: same
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 23 name: bn2b_branch2b
# - name: bn2b_branch2b
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 24 name: activation_54
# - name: activation_54
# - trainable: True
# - dtype: float32
# - activation: relu
# 25 name: res2b_branch2c
# - name: res2b_branch2c
# - trainable: True
# - dtype: float32
# - filters: 256
# - kernel_size: (1, 1)
# - strides: (1, 1)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 26 name: bn2b_branch2c
# - name: bn2b_branch2c
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 27 name: add_17
# - name: add_17
# - trainable: True
# - dtype: float32
# 28 name: activation_55
# - name: activation_55
# - trainable: True
# - dtype: float32
# - activation: relu
# 29 name: res2c_branch2a
# - name: res2c_branch2a
# - trainable: True
# - dtype: float32
# - filters: 64
# - kernel_size: (1, 1)
# - strides: (1, 1)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 30 name: bn2c_branch2a
# - name: bn2c_branch2a
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 31 name: activation_56
# - name: activation_56
# - trainable: True
# - dtype: float32
# - activation: relu
# 32 name: res2c_branch2b
# - name: res2c_branch2b
# - trainable: True
# - dtype: float32
# - filters: 64
# - kernel_size: (3, 3)
# - strides: (1, 1)
# - padding: same
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 33 name: bn2c_branch2b
# - name: bn2c_branch2b
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 34 name: activation_57
# - name: activation_57
# - trainable: True
# - dtype: float32
# - activation: relu
# 35 name: res2c_branch2c
# - name: res2c_branch2c
# - trainable: True
# - dtype: float32
# - filters: 256
# - kernel_size: (1, 1)
# - strides: (1, 1)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 36 name: bn2c_branch2c
# - name: bn2c_branch2c
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 37 name: add_18
# - name: add_18
# - trainable: True
# - dtype: float32
# 38 name: activation_58
# - name: activation_58
# - trainable: True
# - dtype: float32
# - activation: relu
# 39 name: res3a_branch2a
# - name: res3a_branch2a
# - trainable: True
# - dtype: float32
# - filters: 128
# - kernel_size: (1, 1)
# - strides: (2, 2)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 40 name: bn3a_branch2a
# - name: bn3a_branch2a
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 41 name: activation_59
# - name: activation_59
# - trainable: True
# - dtype: float32
# - activation: relu
# 42 name: res3a_branch2b
# - name: res3a_branch2b
# - trainable: True
# - dtype: float32
# - filters: 128
# - kernel_size: (3, 3)
# - strides: (1, 1)
# - padding: same
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 43 name: bn3a_branch2b
# - name: bn3a_branch2b
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 44 name: activation_60
# - name: activation_60
# - trainable: True
# - dtype: float32
# - activation: relu
# 45 name: res3a_branch2c
# - name: res3a_branch2c
# - trainable: True
# - dtype: float32
# - filters: 512
# - kernel_size: (1, 1)
# - strides: (1, 1)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 46 name: res3a_branch1
# - name: res3a_branch1
# - trainable: True
# - dtype: float32
# - filters: 512
# - kernel_size: (1, 1)
# - strides: (2, 2)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 47 name: bn3a_branch2c
# - name: bn3a_branch2c
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 48 name: bn3a_branch1
# - name: bn3a_branch1
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 49 name: add_19
# - name: add_19
# - trainable: True
# - dtype: float32
# 50 name: activation_61
# - name: activation_61
# - trainable: True
# - dtype: float32
# - activation: relu
# 51 name: res3b_branch2a
# - name: res3b_branch2a
# - trainable: True
# - dtype: float32
# - filters: 128
# - kernel_size: (1, 1)
# - strides: (1, 1)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 52 name: bn3b_branch2a
# - name: bn3b_branch2a
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 53 name: activation_62
# - name: activation_62
# - trainable: True
# - dtype: float32
# - activation: relu
# 54 name: res3b_branch2b
# - name: res3b_branch2b
# - trainable: True
# - dtype: float32
# - filters: 128
# - kernel_size: (3, 3)
# - strides: (1, 1)
# - padding: same
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 55 name: bn3b_branch2b
# - name: bn3b_branch2b
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 56 name: activation_63
# - name: activation_63
# - trainable: True
# - dtype: float32
# - activation: relu
# 57 name: res3b_branch2c
# - name: res3b_branch2c
# - trainable: True
# - dtype: float32
# - filters: 512
# - kernel_size: (1, 1)
# - strides: (1, 1)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 58 name: bn3b_branch2c
# - name: bn3b_branch2c
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 59 name: add_20
# - name: add_20
# - trainable: True
# - dtype: float32
# 60 name: activation_64
# - name: activation_64
# - trainable: True
# - dtype: float32
# - activation: relu
# 61 name: res3c_branch2a
# - name: res3c_branch2a
# - trainable: True
# - dtype: float32
# - filters: 128
# - kernel_size: (1, 1)
# - strides: (1, 1)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 62 name: bn3c_branch2a
# - name: bn3c_branch2a
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 63 name: activation_65
# - name: activation_65
# - trainable: True
# - dtype: float32
# - activation: relu
# 64 name: res3c_branch2b
# - name: res3c_branch2b
# - trainable: True
# - dtype: float32
# - filters: 128
# - kernel_size: (3, 3)
# - strides: (1, 1)
# - padding: same
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 65 name: bn3c_branch2b
# - name: bn3c_branch2b
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 66 name: activation_66
# - name: activation_66
# - trainable: True
# - dtype: float32
# - activation: relu
# 67 name: res3c_branch2c
# - name: res3c_branch2c
# - trainable: True
# - dtype: float32
# - filters: 512
# - kernel_size: (1, 1)
# - strides: (1, 1)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 68 name: bn3c_branch2c
# - name: bn3c_branch2c
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 69 name: add_21
# - name: add_21
# - trainable: True
# - dtype: float32
# 70 name: activation_67
# - name: activation_67
# - trainable: True
# - dtype: float32
# - activation: relu
# 71 name: res3d_branch2a
# - name: res3d_branch2a
# - trainable: True
# - dtype: float32
# - filters: 128
# - kernel_size: (1, 1)
# - strides: (1, 1)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 72 name: bn3d_branch2a
# - name: bn3d_branch2a
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 73 name: activation_68
# - name: activation_68
# - trainable: True
# - dtype: float32
# - activation: relu
# 74 name: res3d_branch2b
# - name: res3d_branch2b
# - trainable: True
# - dtype: float32
# - filters: 128
# - kernel_size: (3, 3)
# - strides: (1, 1)
# - padding: same
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 75 name: bn3d_branch2b
# - name: bn3d_branch2b
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 76 name: activation_69
# - name: activation_69
# - trainable: True
# - dtype: float32
# - activation: relu
# 77 name: res3d_branch2c
# - name: res3d_branch2c
# - trainable: True
# - dtype: float32
# - filters: 512
# - kernel_size: (1, 1)
# - strides: (1, 1)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 78 name: bn3d_branch2c
# - name: bn3d_branch2c
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 79 name: add_22
# - name: add_22
# - trainable: True
# - dtype: float32
# 80 name: activation_70
# - name: activation_70
# - trainable: True
# - dtype: float32
# - activation: relu
# 81 name: res4a_branch2a
# - name: res4a_branch2a
# - trainable: True
# - dtype: float32
# - filters: 256
# - kernel_size: (1, 1)
# - strides: (2, 2)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 82 name: bn4a_branch2a
# - name: bn4a_branch2a
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 83 name: activation_71
# - name: activation_71
# - trainable: True
# - dtype: float32
# - activation: relu
# 84 name: res4a_branch2b
# - name: res4a_branch2b
# - trainable: True
# - dtype: float32
# - filters: 256
# - kernel_size: (3, 3)
# - strides: (1, 1)
# - padding: same
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 85 name: bn4a_branch2b
# - name: bn4a_branch2b
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 86 name: activation_72
# - name: activation_72
# - trainable: True
# - dtype: float32
# - activation: relu
# 87 name: res4a_branch2c
# - name: res4a_branch2c
# - trainable: True
# - dtype: float32
# - filters: 1024
# - kernel_size: (1, 1)
# - strides: (1, 1)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 88 name: res4a_branch1
# - name: res4a_branch1
# - trainable: True
# - dtype: float32
# - filters: 1024
# - kernel_size: (1, 1)
# - strides: (2, 2)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 89 name: bn4a_branch2c
# - name: bn4a_branch2c
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 90 name: bn4a_branch1
# - name: bn4a_branch1
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 91 name: add_23
# - name: add_23
# - trainable: True
# - dtype: float32
# 92 name: activation_73
# - name: activation_73
# - trainable: True
# - dtype: float32
# - activation: relu
# 93 name: res4b_branch2a
# - name: res4b_branch2a
# - trainable: True
# - dtype: float32
# - filters: 256
# - kernel_size: (1, 1)
# - strides: (1, 1)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 94 name: bn4b_branch2a
# - name: bn4b_branch2a
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 95 name: activation_74
# - name: activation_74
# - trainable: True
# - dtype: float32
# - activation: relu
# 96 name: res4b_branch2b
# - name: res4b_branch2b
# - trainable: True
# - dtype: float32
# - filters: 256
# - kernel_size: (3, 3)
# - strides: (1, 1)
# - padding: same
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 97 name: bn4b_branch2b
# - name: bn4b_branch2b
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 98 name: activation_75
# - name: activation_75
# - trainable: True
# - dtype: float32
# - activation: relu
# 99 name: res4b_branch2c
# - name: res4b_branch2c
# - trainable: True
# - dtype: float32
# - filters: 1024
# - kernel_size: (1, 1)
# - strides: (1, 1)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 100 name: bn4b_branch2c
# - name: bn4b_branch2c
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 101 name: add_24
# - name: add_24
# - trainable: True
# - dtype: float32
# 102 name: activation_76
# - name: activation_76
# - trainable: True
# - dtype: float32
# - activation: relu
# 103 name: res4c_branch2a
# - name: res4c_branch2a
# - trainable: True
# - dtype: float32
# - filters: 256
# - kernel_size: (1, 1)
# - strides: (1, 1)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 104 name: bn4c_branch2a
# - name: bn4c_branch2a
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 105 name: activation_77
# - name: activation_77
# - trainable: True
# - dtype: float32
# - activation: relu
# 106 name: res4c_branch2b
# - name: res4c_branch2b
# - trainable: True
# - dtype: float32
# - filters: 256
# - kernel_size: (3, 3)
# - strides: (1, 1)
# - padding: same
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 107 name: bn4c_branch2b
# - name: bn4c_branch2b
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 108 name: activation_78
# - name: activation_78
# - trainable: True
# - dtype: float32
# - activation: relu
# 109 name: res4c_branch2c
# - name: res4c_branch2c
# - trainable: True
# - dtype: float32
# - filters: 1024
# - kernel_size: (1, 1)
# - strides: (1, 1)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 110 name: bn4c_branch2c
# - name: bn4c_branch2c
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 111 name: add_25
# - name: add_25
# - trainable: True
# - dtype: float32
# 112 name: activation_79
# - name: activation_79
# - trainable: True
# - dtype: float32
# - activation: relu
# 113 name: res4d_branch2a
# - name: res4d_branch2a
# - trainable: True
# - dtype: float32
# - filters: 256
# - kernel_size: (1, 1)
# - strides: (1, 1)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 114 name: bn4d_branch2a
# - name: bn4d_branch2a
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 115 name: activation_80
# - name: activation_80
# - trainable: True
# - dtype: float32
# - activation: relu
# 116 name: res4d_branch2b
# - name: res4d_branch2b
# - trainable: True
# - dtype: float32
# - filters: 256
# - kernel_size: (3, 3)
# - strides: (1, 1)
# - padding: same
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 117 name: bn4d_branch2b
# - name: bn4d_branch2b
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 118 name: activation_81
# - name: activation_81
# - trainable: True
# - dtype: float32
# - activation: relu
# 119 name: res4d_branch2c
# - name: res4d_branch2c
# - trainable: True
# - dtype: float32
# - filters: 1024
# - kernel_size: (1, 1)
# - strides: (1, 1)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# ...
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 135 name: activation_86
# - name: activation_86
# - trainable: True
# - dtype: float32
# - activation: relu
# 136 name: res4f_branch2b
# - name: res4f_branch2b
# - trainable: True
# - dtype: float32
# - filters: 256
# - kernel_size: (3, 3)
# - strides: (1, 1)
# - padding: same
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 137 name: bn4f_branch2b
# - name: bn4f_branch2b
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 138 name: activation_87
# - name: activation_87
# - trainable: True
# - dtype: float32
# - activation: relu
# 139 name: res4f_branch2c
# - name: res4f_branch2c
# - trainable: True
# - dtype: float32
# - filters: 1024
# - kernel_size: (1, 1)
# - strides: (1, 1)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 140 name: bn4f_branch2c
# - name: bn4f_branch2c
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 141 name: add_28
# - name: add_28
# - trainable: True
# - dtype: float32
# 142 name: activation_88
# - name: activation_88
# - trainable: True
# - dtype: float32
# - activation: relu
# 143 name: res5a_branch2a
# - name: res5a_branch2a
# - trainable: True
# - dtype: float32
# - filters: 512
# - kernel_size: (1, 1)
# - strides: (2, 2)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 144 name: bn5a_branch2a
# - name: bn5a_branch2a
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 145 name: activation_89
# - name: activation_89
# - trainable: True
# - dtype: float32
# - activation: relu
# 146 name: res5a_branch2b
# - name: res5a_branch2b
# - trainable: True
# - dtype: float32
# - filters: 512
# - kernel_size: (3, 3)
# - strides: (1, 1)
# - padding: same
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 147 name: bn5a_branch2b
# - name: bn5a_branch2b
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 148 name: activation_90
# - name: activation_90
# - trainable: True
# - dtype: float32
# - activation: relu
# 149 name: res5a_branch2c
# - name: res5a_branch2c
# - trainable: True
# - dtype: float32
# - filters: 2048
# - kernel_size: (1, 1)
# - strides: (1, 1)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 150 name: res5a_branch1
# - name: res5a_branch1
# - trainable: True
# - dtype: float32
# - filters: 2048
# - kernel_size: (1, 1)
# - strides: (2, 2)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 151 name: bn5a_branch2c
# - name: bn5a_branch2c
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 152 name: bn5a_branch1
# - name: bn5a_branch1
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 153 name: add_29
# - name: add_29
# - trainable: True
# - dtype: float32
# 154 name: activation_91
# - name: activation_91
# - trainable: True
# - dtype: float32
# - activation: relu
# 155 name: res5b_branch2a
# - name: res5b_branch2a
# - trainable: True
# - dtype: float32
# - filters: 512
# - kernel_size: (1, 1)
# - strides: (1, 1)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 156 name: bn5b_branch2a
# - name: bn5b_branch2a
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 157 name: activation_92
# - name: activation_92
# - trainable: True
# - dtype: float32
# - activation: relu
# 158 name: res5b_branch2b
# - name: res5b_branch2b
# - trainable: True
# - dtype: float32
# - filters: 512
# - kernel_size: (3, 3)
# - strides: (1, 1)
# - padding: same
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 159 name: bn5b_branch2b
# - name: bn5b_branch2b
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 160 name: activation_93
# - name: activation_93
# - trainable: True
# - dtype: float32
# - activation: relu
# 161 name: res5b_branch2c
# - name: res5b_branch2c
# - trainable: True
# - dtype: float32
# - filters: 2048
# - kernel_size: (1, 1)
# - strides: (1, 1)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 162 name: bn5b_branch2c
# - name: bn5b_branch2c
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 163 name: add_30
# - name: add_30
# - trainable: True
# - dtype: float32
# 164 name: activation_94
# - name: activation_94
# - trainable: True
# - dtype: float32
# - activation: relu
# 165 name: res5c_branch2a
# - name: res5c_branch2a
# - trainable: True
# - dtype: float32
# - filters: 512
# - kernel_size: (1, 1)
# - strides: (1, 1)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 166 name: bn5c_branch2a
# - name: bn5c_branch2a
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 167 name: activation_95
# - name: activation_95
# - trainable: True
# - dtype: float32
# - activation: relu
# 168 name: res5c_branch2b
# - name: res5c_branch2b
# - trainable: True
# - dtype: float32
# - filters: 512
# - kernel_size: (3, 3)
# - strides: (1, 1)
# - padding: same
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 169 name: bn5c_branch2b
# - name: bn5c_branch2b
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 170 name: activation_96
# - name: activation_96
# - trainable: True
# - dtype: float32
# - activation: relu
# 171 name: res5c_branch2c
# - name: res5c_branch2c
# - trainable: True
# - dtype: float32
# - filters: 2048
# - kernel_size: (1, 1)
# - strides: (1, 1)
# - padding: valid
# - data_format: channels_last
# - dilation_rate: (1, 1)
# - activation: linear
# - use_bias: True
# - kernel_initializer: {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'truncated_normal', 'seed': None, 'dtype': 'float32'}}
# - bias_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - kernel_regularizer: None
# - bias_regularizer: None
# - activity_regularizer: None
# - kernel_constraint: None
# - bias_constraint: None
# 172 name: bn5c_branch2c
# - name: bn5c_branch2c
# - trainable: True
# - dtype: float32
# - axis: [3]
# - momentum: 0.99
# - epsilon: 0.001
# - center: True
# - scale: True
# - beta_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - gamma_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - moving_mean_initializer: {'class_name': 'Zeros', 'config': {'dtype': 'float32'}}
# - moving_variance_initializer: {'class_name': 'Ones', 'config': {'dtype': 'float32'}}
# - beta_regularizer: None
# - gamma_regularizer: None
# - beta_constraint: None
# - gamma_constraint: None
# 173 name: add_31
# - name: add_31
# - trainable: True
# - dtype: float32
# 174 name: activation_97
# - name: activation_97
# - trainable: True
# - dtype: float32
# - activation: relu

# %%
df = pd.DataFrame(data=output)
df.set_index('_layer_id', drop=True, inplace=True)

# %%
df.columns = sorted(df.columns)

# %%
df.iloc[91]
# Out:
# _name                           add_23
# activation                         NaN
# activity_regularizer               NaN
# axis                               NaN
# batch_input_shape                  NaN
# beta_constraint                    NaN
# beta_initializer                   NaN
# beta_regularizer                   NaN
# bias_constraint                    NaN
# bias_initializer                   NaN
# bias_regularizer                   NaN
# center                             NaN
# data_format                        NaN
# dilation_rate                      NaN
# dtype                          float32
# epsilon                            NaN
# filters                            NaN
# gamma_constraint                   NaN
# gamma_initializer                  NaN
# gamma_regularizer                  NaN
# kernel_constraint                  NaN
# kernel_initializer                 NaN
# kernel_regularizer                 NaN
# kernel_size                        NaN
# momentum                           NaN
# moving_mean_initializer            NaN
# moving_variance_initializer        NaN
# name                            add_23
# padding                            NaN
# pool_size                          NaN
# scale                              NaN
# sparse                             NaN
# strides                            NaN
# trainable                         True
# use_bias                           NaN
# Name: 91, dtype: object

# %%
df[['_name', 'filters', 'kernel_size', 'padding', 'pool_size']].to_csv(output_path / "layers.csv")
